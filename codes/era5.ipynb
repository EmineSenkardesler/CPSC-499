# %%
pip install xarray zarr gcsfs fsspec pandas geopandas rasterstats

# %% [markdown]
# - xarray: For handling Zarr datasets.
# - zarr and gcsfs: For accessing Zarr files on GCS.
# - fsspec: For file system abstraction.

# %% [markdown]
# ## Google Cloud data subset maintained by ARCO-ERA5 at Google (lagged by three months)

# %%
import xarray as xr
import gcsfs
import pandas as pd

# %%
# Initialize GCS file system (no authentication needed for public data)
gcs = gcsfs.GCSFileSystem(token='anon')

# Specify the Zarr store (cloud-optimized single-level reanalysis)
zarr_path = 'gs://gcp-public-data-arco-era5/co/single-level-reanalysis.zarr'

# Open the Zarr store with xarray
ds = xr.open_zarr(zarr_path, consolidated=True, storage_options={'token': 'anon'})

# %%
ds
# Out:
# <xarray.Dataset> Size: 4PB
# Dimensions:                                                          (
#                                                                       time: 1323648,
#                                                                       latitude: 721,
#                                                                       longitude: 1440,
#                                                                       level: 37)
# Coordinates:
#   * latitude                                                         (latitude) float32 3kB ...
#   * level                                                            (level) int64 296B ...
#   * longitude                                                        (longitude) float32 6kB ...
#   * time                                                             (time) datetime64[ns] 11MB ...
# Data variables: (12/273)
#     100m_u_component_of_wind                                         (time, latitude, longitude) float32 5TB ...
#     100m_v_component_of_wind                                         (time, latitude, longitude) float32 5TB ...
#     10m_u_component_of_neutral_wind                                  (time, latitude, longitude) float32 5TB ...
#     10m_u_component_of_wind                                          (time, latitude, longitude) float32 5TB ...
#     10m_v_component_of_neutral_wind                                  (time, latitude, longitude) float32 5TB ...
#     10m_v_component_of_wind                                          (time, latitude, longitude) float32 5TB ...
#     ...                                                               ...
#     wave_spectral_directional_width_for_swell                        (time, latitude, longitude) float32 5TB ...
#     wave_spectral_directional_width_for_wind_waves                   (time, latitude, longitude) float32 5TB ...
#     wave_spectral_kurtosis                                           (time, latitude, longitude) float32 5TB ...
#     wave_spectral_peakedness                                         (time, latitude, longitude) float32 5TB ...
#     wave_spectral_skewness                                           (time, latitude, longitude) float32 5TB ...
#     zero_degree_level                                                (time, latitude, longitude) float32 5TB ...
# Attributes:
#     valid_time_start:       1940-01-01
#     last_updated:           2025-05-05 02:19:41.078356+00:00
#     valid_time_stop:        2025-01-31
#     valid_time_stop_era5t:  2025-04-29

# %%
import xarray as xr
import gcsfs

# 1) Point to the ARCO-ERA5 Analysis-Ready store
ar_zarr = "gs://gcp-public-data-arco-era5/ar/full_37-1h-0p25deg-chunk-1.zarr-v3"

# 2) Open with anonymous GCS credentials
gcs = gcsfs.GCSFileSystem(token="anon")
ds = xr.open_zarr(
    ar_zarr,
    consolidated=True,
    storage_options={"token": "anon"}
)

# (Optional) Inspect dims & coords to confirm names
print(ds.dims)        # e.g. ('time','latitude','longitude','level')
print(ds.coords)      # to see lat/lon ranges
print(ds.data_vars)   # to see '2t' in the dataset

# 3) Define Illinois bounding box (approximate)
#    Latitude: 36.95°N (south) → 42.50°N (north)
#    Longitude: –91.5° (west) → –87.0° (east)
lat_min, lat_max = 36.95, 42.50
lon_min, lon_max = -91.50, -87.00

# 4) Slice out just the 2 m temperature ("2t") over IL
ds_il_temp = (
    ds["2m_temperature"]
      .sel(
        time     = slice(ds.attrs["valid_time_start"], ds.attrs["valid_time_stop"]),
        latitude = slice(lat_max, lat_min),   # slice(high, low) if coord is descending
        longitude= slice(lon_min, lon_max)
      )
      .load()  # actually pull the data
)

print(ds_il_temp)
# Out:
# FrozenMappingWarningOnValuesAccess({'time': 1323648, 'latitude': 721, 'longitude': 1440, 'level': 37})
# Coordinates:
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * level      (level) int64 296B 1 2 3 5 7 10 20 ... 875 900 925 950 975 1000
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * time       (time) datetime64[ns] 11MB 1900-01-01 ... 2050-12-31T23:00:00
# Data variables:
#     100m_u_component_of_wind                                         (time, latitude, longitude) float32 5TB ...
#     100m_v_component_of_wind                                         (time, latitude, longitude) float32 5TB ...
#     10m_u_component_of_neutral_wind                                  (time, latitude, longitude) float32 5TB ...
#     10m_u_component_of_wind                                          (time, latitude, longitude) float32 5TB ...
#     10m_v_component_of_neutral_wind                                  (time, latitude, longitude) float32 5TB ...
#     10m_v_component_of_wind                                          (time, latitude, longitude) float32 5TB ...
#     10m_wind_gust_since_previous_post_processing                     (time, latitude, longitude) float32 5TB ...
#     2m_dewpoint_temperature                                          (time, latitude, longitude) float32 5TB ...
#     2m_temperature                                                   (time, latitude, longitude) float32 5TB ...
#     air_density_over_the_oceans                                      (time, latitude, longitude) float32 5TB ...
#     angle_of_sub_gridscale_orography                                 (time, latitude, longitude) float32 5TB ...
#     anisotropy_of_sub_gridscale_orography                            (time, latitude, longitude) float32 5TB ...
#     benjamin_feir_index                                              (time, latitude, longitude) float32 5TB ...
#     boundary_layer_dissipation                                       (time, latitude, longitude) float32 5TB ...
#     boundary_layer_height                                            (time, latitude, longitude) float32 5TB ...
#     charnock                                                         (time, latitude, longitude) float32 5TB ...
#     clear_sky_direct_solar_radiation_at_surface                      (time, latitude, longitude) float32 5TB ...
#     cloud_base_height                                                (time, latitude, longitude) float32 5TB ...
#     coefficient_of_drag_with_waves                                   (time, latitude, longitude) float32 5TB ...
#     convective_available_potential_energy                            (time, latitude, longitude) float32 5TB ...
#     convective_inhibition                                            (time, latitude, longitude) float32 5TB ...
#     convective_precipitation                                         (time, latitude, longitude) float32 5TB ...
#     convective_rain_rate                                             (time, latitude, longitude) float32 5TB ...
#     convective_snowfall                                              (time, latitude, longitude) float32 5TB ...
#     convective_snowfall_rate_water_equivalent                        (time, latitude, longitude) float32 5TB ...
#     downward_uv_radiation_at_the_surface                             (time, latitude, longitude) float32 5TB ...
#     duct_base_height                                                 (time, latitude, longitude) float32 5TB ...
#     eastward_gravity_wave_surface_stress                             (time, latitude, longitude) float32 5TB ...
#     eastward_turbulent_surface_stress                                (time, latitude, longitude) float32 5TB ...
#     evaporation                                                      (time, latitude, longitude) float32 5TB ...
#     forecast_albedo                                                  (time, latitude, longitude) float32 5TB ...
#     forecast_logarithm_of_surface_roughness_for_heat                 (time, latitude, longitude) float32 5TB ...
#     forecast_surface_roughness                                       (time, latitude, longitude) float32 5TB ...
#     fraction_of_cloud_cover                                          (time, level, latitude, longitude) float32 203TB ...
#     free_convective_velocity_over_the_oceans                         (time, latitude, longitude) float32 5TB ...
#     friction_velocity                                                (time, latitude, longitude) float32 5TB ...
#     geopotential                                                     (time, level, latitude, longitude) float32 203TB ...
#     geopotential_at_surface                                          (time, latitude, longitude) float32 5TB ...
#     gravity_wave_dissipation                                         (time, latitude, longitude) float32 5TB ...
#     high_cloud_cover                                                 (time, latitude, longitude) float32 5TB ...
#     high_vegetation_cover                                            (time, latitude, longitude) float32 5TB ...
#     ice_temperature_layer_1                                          (time, latitude, longitude) float32 5TB ...
#     ice_temperature_layer_2                                          (time, latitude, longitude) float32 5TB ...
#     ice_temperature_layer_3                                          (time, latitude, longitude) float32 5TB ...
#     ice_temperature_layer_4                                          (time, latitude, longitude) float32 5TB ...
#     instantaneous_10m_wind_gust                                      (time, latitude, longitude) float32 5TB ...
#     instantaneous_eastward_turbulent_surface_stress                  (time, latitude, longitude) float32 5TB ...
#     instantaneous_large_scale_surface_precipitation_fraction         (time, latitude, longitude) float32 5TB ...
#     instantaneous_moisture_flux                                      (time, latitude, longitude) float32 5TB ...
#     instantaneous_northward_turbulent_surface_stress                 (time, latitude, longitude) float32 5TB ...
#     instantaneous_surface_sensible_heat_flux                         (time, latitude, longitude) float32 5TB ...
#     k_index                                                          (time, latitude, longitude) float32 5TB ...
#     lake_bottom_temperature                                          (time, latitude, longitude) float32 5TB ...
#     lake_cover                                                       (time, latitude, longitude) float32 5TB ...
#     lake_depth                                                       (time, latitude, longitude) float32 5TB ...
#     lake_ice_depth                                                   (time, latitude, longitude) float32 5TB ...
#     lake_ice_temperature                                             (time, latitude, longitude) float32 5TB ...
#     lake_mix_layer_depth                                             (time, latitude, longitude) float32 5TB ...
#     lake_mix_layer_temperature                                       (time, latitude, longitude) float32 5TB ...
#     lake_shape_factor                                                (time, latitude, longitude) float32 5TB ...
#     lake_total_layer_temperature                                     (time, latitude, longitude) float32 5TB ...
#     land_sea_mask                                                    (time, latitude, longitude) float32 5TB ...
#     large_scale_precipitation                                        (time, latitude, longitude) float32 5TB ...
#     large_scale_precipitation_fraction                               (time, latitude, longitude) float32 5TB ...
#     large_scale_rain_rate                                            (time, latitude, longitude) float32 5TB ...
#     large_scale_snowfall                                             (time, latitude, longitude) float32 5TB ...
#     large_scale_snowfall_rate_water_equivalent                       (time, latitude, longitude) float32 5TB ...
#     leaf_area_index_high_vegetation                                  (time, latitude, longitude) float32 5TB ...
#     leaf_area_index_low_vegetation                                   (time, latitude, longitude) float32 5TB ...
#     low_cloud_cover                                                  (time, latitude, longitude) float32 5TB ...
#     low_vegetation_cover                                             (time, latitude, longitude) float32 5TB ...
#     maximum_2m_temperature_since_previous_post_processing            (time, latitude, longitude) float32 5TB ...
#     maximum_individual_wave_height                                   (time, latitude, longitude) float32 5TB ...
#     maximum_total_precipitation_rate_since_previous_post_processing  (time, latitude, longitude) float32 5TB ...
#     mean_boundary_layer_dissipation                                  (time, latitude, longitude) float32 5TB ...
#     mean_convective_precipitation_rate                               (time, latitude, longitude) float32 5TB ...
#     mean_convective_snowfall_rate                                    (time, latitude, longitude) float32 5TB ...
#     mean_direction_of_total_swell                                    (time, latitude, longitude) float32 5TB ...
#     mean_direction_of_wind_waves                                     (time, latitude, longitude) float32 5TB ...
#     mean_eastward_gravity_wave_surface_stress                        (time, latitude, longitude) float32 5TB ...
#     mean_eastward_turbulent_surface_stress                           (time, latitude, longitude) float32 5TB ...
#     mean_evaporation_rate                                            (time, latitude, longitude) float32 5TB ...
#     mean_gravity_wave_dissipation                                    (time, latitude, longitude) float32 5TB ...
#     mean_large_scale_precipitation_fraction                          (time, latitude, longitude) float32 5TB ...
#     mean_large_scale_precipitation_rate                              (time, latitude, longitude) float32 5TB ...
#     mean_large_scale_snowfall_rate                                   (time, latitude, longitude) float32 5TB ...
#     mean_northward_gravity_wave_surface_stress                       (time, latitude, longitude) float32 5TB ...
#     mean_northward_turbulent_surface_stress                          (time, latitude, longitude) float32 5TB ...
#     mean_period_of_total_swell                                       (time, latitude, longitude) float32 5TB ...
#     mean_period_of_wind_waves                                        (time, latitude, longitude) float32 5TB ...
#     mean_potential_evaporation_rate                                  (time, latitude, longitude) float32 5TB ...
#     mean_runoff_rate                                                 (time, latitude, longitude) float32 5TB ...
#     mean_sea_level_pressure                                          (time, latitude, longitude) float32 5TB ...
#     mean_snow_evaporation_rate                                       (time, latitude, longitude) float32 5TB ...
#     mean_snowfall_rate                                               (time, latitude, longitude) float32 5TB ...
#     mean_snowmelt_rate                                               (time, latitude, longitude) float32 5TB ...
#     mean_square_slope_of_waves                                       (time, latitude, longitude) float32 5TB ...
#     mean_sub_surface_runoff_rate                                     (time, latitude, longitude) float32 5TB ...
#     mean_surface_direct_short_wave_radiation_flux                    (time, latitude, longitude) float32 5TB ...
#     mean_surface_direct_short_wave_radiation_flux_clear_sky          (time, latitude, longitude) float32 5TB ...
#     mean_surface_downward_long_wave_radiation_flux                   (time, latitude, longitude) float32 5TB ...
#     mean_surface_downward_long_wave_radiation_flux_clear_sky         (time, latitude, longitude) float32 5TB ...
#     mean_surface_downward_short_wave_radiation_flux                  (time, latitude, longitude) float32 5TB ...
#     mean_surface_downward_short_wave_radiation_flux_clear_sky        (time, latitude, longitude) float32 5TB ...
#     mean_surface_downward_uv_radiation_flux                          (time, latitude, longitude) float32 5TB ...
#     mean_surface_latent_heat_flux                                    (time, latitude, longitude) float32 5TB ...
#     mean_surface_net_long_wave_radiation_flux                        (time, latitude, longitude) float32 5TB ...
#     mean_surface_net_long_wave_radiation_flux_clear_sky              (time, latitude, longitude) float32 5TB ...
#     mean_surface_net_short_wave_radiation_flux                       (time, latitude, longitude) float32 5TB ...
#     mean_surface_net_short_wave_radiation_flux_clear_sky             (time, latitude, longitude) float32 5TB ...
#     mean_surface_runoff_rate                                         (time, latitude, longitude) float32 5TB ...
#     mean_surface_sensible_heat_flux                                  (time, latitude, longitude) float32 5TB ...
#     mean_top_downward_short_wave_radiation_flux                      (time, latitude, longitude) float32 5TB ...
#     mean_top_net_long_wave_radiation_flux                            (time, latitude, longitude) float32 5TB ...
#     mean_top_net_long_wave_radiation_flux_clear_sky                  (time, latitude, longitude) float32 5TB ...
#     mean_top_net_short_wave_radiation_flux                           (time, latitude, longitude) float32 5TB ...
#     mean_top_net_short_wave_radiation_flux_clear_sky                 (time, latitude, longitude) float32 5TB ...
#     mean_total_precipitation_rate                                    (time, latitude, longitude) float32 5TB ...
#     mean_vertical_gradient_of_refractivity_inside_trapping_layer     (time, latitude, longitude) float32 5TB ...
#     mean_vertically_integrated_moisture_divergence                   (time, latitude, longitude) float32 5TB ...
#     mean_wave_direction                                              (time, latitude, longitude) float32 5TB ...
#     mean_wave_direction_of_first_swell_partition                     (time, latitude, longitude) float32 5TB ...
#     mean_wave_direction_of_second_swell_partition                    (time, latitude, longitude) float32 5TB ...
#     mean_wave_direction_of_third_swell_partition                     (time, latitude, longitude) float32 5TB ...
#     mean_wave_period                                                 (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_based_on_first_moment                           (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_based_on_first_moment_for_swell                 (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_based_on_first_moment_for_wind_waves            (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_based_on_second_moment_for_swell                (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_based_on_second_moment_for_wind_waves           (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_of_first_swell_partition                        (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_of_second_swell_partition                       (time, latitude, longitude) float32 5TB ...
#     mean_wave_period_of_third_swell_partition                        (time, latitude, longitude) float32 5TB ...
#     mean_zero_crossing_wave_period                                   (time, latitude, longitude) float32 5TB ...
#     medium_cloud_cover                                               (time, latitude, longitude) float32 5TB ...
#     minimum_2m_temperature_since_previous_post_processing            (time, latitude, longitude) float32 5TB ...
#     minimum_total_precipitation_rate_since_previous_post_processing  (time, latitude, longitude) float32 5TB ...
#     minimum_vertical_gradient_of_refractivity_inside_trapping_layer  (time, latitude, longitude) float32 5TB ...
#     model_bathymetry                                                 (time, latitude, longitude) float32 5TB ...
#     near_ir_albedo_for_diffuse_radiation                             (time, latitude, longitude) float32 5TB ...
#     near_ir_albedo_for_direct_radiation                              (time, latitude, longitude) float32 5TB ...
#     normalized_energy_flux_into_ocean                                (time, latitude, longitude) float32 5TB ...
#     normalized_energy_flux_into_waves                                (time, latitude, longitude) float32 5TB ...
#     normalized_stress_into_ocean                                     (time, latitude, longitude) float32 5TB ...
#     northward_gravity_wave_surface_stress                            (time, latitude, longitude) float32 5TB ...
#     northward_turbulent_surface_stress                               (time, latitude, longitude) float32 5TB ...
#     ocean_surface_stress_equivalent_10m_neutral_wind_direction       (time, latitude, longitude) float32 5TB ...
#     ocean_surface_stress_equivalent_10m_neutral_wind_speed           (time, latitude, longitude) float32 5TB ...
#     ozone_mass_mixing_ratio                                          (time, level, latitude, longitude) float32 203TB ...
#     peak_wave_period                                                 (time, latitude, longitude) float32 5TB ...
#     period_corresponding_to_maximum_individual_wave_height           (time, latitude, longitude) float32 5TB ...
#     potential_evaporation                                            (time, latitude, longitude) float32 5TB ...
#     potential_vorticity                                              (time, level, latitude, longitude) float32 203TB ...
#     precipitation_type                                               (time, latitude, longitude) float32 5TB ...
#     runoff                                                           (time, latitude, longitude) float32 5TB ...
#     sea_ice_cover                                                    (time, latitude, longitude) float32 5TB ...
#     sea_surface_temperature                                          (time, latitude, longitude) float32 5TB ...
#     significant_height_of_combined_wind_waves_and_swell              (time, latitude, longitude) float32 5TB ...
#     significant_height_of_total_swell                                (time, latitude, longitude) float32 5TB ...
#     significant_height_of_wind_waves                                 (time, latitude, longitude) float32 5TB ...
#     significant_wave_height_of_first_swell_partition                 (time, latitude, longitude) float32 5TB ...
#     significant_wave_height_of_second_swell_partition                (time, latitude, longitude) float32 5TB ...
#     significant_wave_height_of_third_swell_partition                 (time, latitude, longitude) float32 5TB ...
#     skin_reservoir_content                                           (time, latitude, longitude) float32 5TB ...
#     skin_temperature                                                 (time, latitude, longitude) float32 5TB ...
#     slope_of_sub_gridscale_orography                                 (time, latitude, longitude) float32 5TB ...
#     snow_albedo                                                      (time, latitude, longitude) float32 5TB ...
#     snow_density                                                     (time, latitude, longitude) float32 5TB ...
#     snow_depth                                                       (time, latitude, longitude) float32 5TB ...
#     snow_evaporation                                                 (time, latitude, longitude) float32 5TB ...
#     snowfall                                                         (time, latitude, longitude) float32 5TB ...
#     snowmelt                                                         (time, latitude, longitude) float32 5TB ...
#     soil_temperature_level_1                                         (time, latitude, longitude) float32 5TB ...
#     soil_temperature_level_2                                         (time, latitude, longitude) float32 5TB ...
#     soil_temperature_level_3                                         (time, latitude, longitude) float32 5TB ...
#     soil_temperature_level_4                                         (time, latitude, longitude) float32 5TB ...
#     soil_type                                                        (time, latitude, longitude) float32 5TB ...
#     specific_cloud_ice_water_content                                 (time, level, latitude, longitude) float32 203TB ...
#     specific_cloud_liquid_water_content                              (time, level, latitude, longitude) float32 203TB ...
#     specific_humidity                                                (time, level, latitude, longitude) float32 203TB ...
#     standard_deviation_of_filtered_subgrid_orography                 (time, latitude, longitude) float32 5TB ...
#     standard_deviation_of_orography                                  (time, latitude, longitude) float32 5TB ...
#     sub_surface_runoff                                               (time, latitude, longitude) float32 5TB ...
#     surface_latent_heat_flux                                         (time, latitude, longitude) float32 5TB ...
#     surface_net_solar_radiation                                      (time, latitude, longitude) float32 5TB ...
#     surface_net_solar_radiation_clear_sky                            (time, latitude, longitude) float32 5TB ...
#     surface_net_thermal_radiation                                    (time, latitude, longitude) float32 5TB ...
#     surface_net_thermal_radiation_clear_sky                          (time, latitude, longitude) float32 5TB ...
#     surface_pressure                                                 (time, latitude, longitude) float32 5TB ...
#     surface_runoff                                                   (time, latitude, longitude) float32 5TB ...
#     surface_sensible_heat_flux                                       (time, latitude, longitude) float32 5TB ...
#     surface_solar_radiation_downward_clear_sky                       (time, latitude, longitude) float32 5TB ...
#     surface_solar_radiation_downwards                                (time, latitude, longitude) float32 5TB ...
#     surface_thermal_radiation_downward_clear_sky                     (time, latitude, longitude) float32 5TB ...
#     surface_thermal_radiation_downwards                              (time, latitude, longitude) float32 5TB ...
#     temperature                                                      (time, level, latitude, longitude) float32 203TB ...
#     temperature_of_snow_layer                                        (time, latitude, longitude) float32 5TB ...
#     toa_incident_solar_radiation                                     (time, latitude, longitude) float32 5TB ...
#     top_net_solar_radiation                                          (time, latitude, longitude) float32 5TB ...
#     top_net_solar_radiation_clear_sky                                (time, latitude, longitude) float32 5TB ...
#     top_net_thermal_radiation                                        (time, latitude, longitude) float32 5TB ...
#     top_net_thermal_radiation_clear_sky                              (time, latitude, longitude) float32 5TB ...
#     total_cloud_cover                                                (time, latitude, longitude) float32 5TB ...
#     total_column_cloud_ice_water                                     (time, latitude, longitude) float32 5TB ...
#     total_column_cloud_liquid_water                                  (time, latitude, longitude) float32 5TB ...
#     total_column_ozone                                               (time, latitude, longitude) float32 5TB ...
#     total_column_rain_water                                          (time, latitude, longitude) float32 5TB ...
#     total_column_snow_water                                          (time, latitude, longitude) float32 5TB ...
#     total_column_supercooled_liquid_water                            (time, latitude, longitude) float32 5TB ...
#     total_column_water                                               (time, latitude, longitude) float32 5TB ...
#     total_column_water_vapour                                        (time, latitude, longitude) float32 5TB ...
#     total_precipitation                                              (time, latitude, longitude) float32 5TB ...
#     total_sky_direct_solar_radiation_at_surface                      (time, latitude, longitude) float32 5TB ...
#     total_totals_index                                               (time, latitude, longitude) float32 5TB ...
#     trapping_layer_base_height                                       (time, latitude, longitude) float32 5TB ...
#     trapping_layer_top_height                                        (time, latitude, longitude) float32 5TB ...
#     type_of_high_vegetation                                          (time, latitude, longitude) float32 5TB ...
#     type_of_low_vegetation                                           (time, latitude, longitude) float32 5TB ...
#     u_component_of_wind                                              (time, level, latitude, longitude) float32 203TB ...
#     u_component_stokes_drift                                         (time, latitude, longitude) float32 5TB ...
#     uv_visible_albedo_for_diffuse_radiation                          (time, latitude, longitude) float32 5TB ...
#     uv_visible_albedo_for_direct_radiation                           (time, latitude, longitude) float32 5TB ...
#     v_component_of_wind                                              (time, level, latitude, longitude) float32 203TB ...
#     v_component_stokes_drift                                         (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_cloud_frozen_water_flux       (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_cloud_liquid_water_flux       (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_geopotential_flux             (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_kinetic_energy_flux           (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_mass_flux                     (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_moisture_flux                 (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_ozone_flux                    (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_thermal_energy_flux           (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_divergence_of_total_energy_flux             (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_cloud_frozen_water_flux            (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_cloud_liquid_water_flux            (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_geopotential_flux                  (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_heat_flux                          (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_kinetic_energy_flux                (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_mass_flux                          (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_ozone_flux                         (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_total_energy_flux                  (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_eastward_water_vapour_flux                  (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_energy_conversion                           (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_kinetic_energy                              (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_mass_of_atmosphere                          (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_mass_tendency                               (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_cloud_frozen_water_flux           (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_cloud_liquid_water_flux           (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_geopotential_flux                 (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_heat_flux                         (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_kinetic_energy_flux               (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_mass_flux                         (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_ozone_flux                        (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_total_energy_flux                 (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_northward_water_vapour_flux                 (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_potential_and_internal_energy               (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_potential_internal_and_latent_energy        (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_temperature                                 (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_thermal_energy                              (time, latitude, longitude) float32 5TB ...
#     vertical_integral_of_total_energy                                (time, latitude, longitude) float32 5TB ...
#     vertical_velocity                                                (time, level, latitude, longitude) float32 203TB ...
#     vertically_integrated_moisture_divergence                        (time, latitude, longitude) float32 5TB ...
#     volumetric_soil_water_layer_1                                    (time, latitude, longitude) float32 5TB ...
#     volumetric_soil_water_layer_2                                    (time, latitude, longitude) float32 5TB ...
#     volumetric_soil_water_layer_3                                    (time, latitude, longitude) float32 5TB ...
#     volumetric_soil_water_layer_4                                    (time, latitude, longitude) float32 5TB ...
#     wave_spectral_directional_width                                  (time, latitude, longitude) float32 5TB ...
#     wave_spectral_directional_width_for_swell                        (time, latitude, longitude) float32 5TB ...
#     wave_spectral_directional_width_for_wind_waves                   (time, latitude, longitude) float32 5TB ...
#     wave_spectral_kurtosis                                           (time, latitude, longitude) float32 5TB ...
#     wave_spectral_peakedness                                         (time, latitude, longitude) float32 5TB ...
#     wave_spectral_skewness                                           (time, latitude, longitude) float32 5TB ...
#     zero_degree_level                                                (time, latitude, longitude) float32 5TB ...
# <xarray.DataArray '2m_temperature' (time: 745872, latitude: 23, longitude: 0)> Size: 0B
# array([], shape=(745872, 23, 0), dtype=float32)
# Coordinates:
#   * latitude   (latitude) float32 92B 42.5 42.25 42.0 41.75 ... 37.5 37.25 37.0
#   * longitude  (longitude) float32 0B
#   * time       (time) datetime64[ns] 6MB 1940-01-01 ... 2025-01-31T23:00:00
# Attributes:
#     long_name:   2 metre temperature
#     short_name:  t2m
#     units:       K

# %%
print(ds_il_temp)
# Out:
# <xarray.DataArray '2m_temperature' (time: 745872, latitude: 23, longitude: 0)> Size: 0B
# array([], shape=(745872, 23, 0), dtype=float32)
# Coordinates:
#   * latitude   (latitude) float32 92B 42.5 42.25 42.0 41.75 ... 37.5 37.25 37.0
#   * longitude  (longitude) float32 0B
#   * time       (time) datetime64[ns] 6MB 1940-01-01 ... 2025-01-31T23:00:00
# Attributes:
#     long_name:   2 metre temperature
#     short_name:  t2m
#     units:       K

# %%
# 5) Save to a local NetCDF for downstream use
ds_il_temp.to_netcdf("IL_2m_temperature_ERA5_AR_1979-present.nc")

# %%
df = ds_il_temp.to_dataframe()
#df.to_csv('era5_subset.csv')
df

# %%
# Convert units
ds_subset['2m_temperature'] = ds_subset['2m_temperature'] - 273.15  # Kelvin to Celsius
ds_subset['total_precipitation'] = ds_subset['total_precipitation'] * 1000  # Meters to mm

# Save to a local NetCDF file (optional, for smaller subsets)
ds_subset.to_netcdf('era5_subset.nc')
